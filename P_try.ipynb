# %% [markdown]
# <a href="https://colab.research.google.com/github/623020514-5/stat-Ubon/blob/main/P_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
Data_ori = pd.read_csv('/content/drive/MyDrive/โครงงานสหกิจ/IES 2565 (2022)/Microdata IES 2565/Microdata IES 2565_N_NEW.csv')
Data_ori
# Out:
#          NUM_B  REG  CWT  AREA  PSU_NO  EA_SET SAMSET  MONTH  YR  HH_NO  ...  \
# 0            1    1   10     1       1       1      D      7  65      7  ...
# 1            2    1   10     1       1       1      D      7  65      7  ...
# 2            3    1   10     1       1       1      D      7  65      7  ...
# 3            4    1   10     1       1       1      D      7  65      8  ...
# 4            5    1   10     1       1       1      D      7  65      8  ...
# ...        ...  ...  ...   ...     ...     ...    ...    ...  ..    ...  ...
# 208893  208894    5   96     1      18       1      D      9  65      4  ...
# 208894  208895    5   96     1      18       1      D      9  65      5  ...
# 208895  208896    5   96     1      18       1      D      9  65      5  ...
# 208896  208897    5   96     1      18       1      D      9  65      5  ...
# 208897  208898    5   96     1      18       1      D      9  65      5  ...
#
# ...

# %% [markdown]
# > การคัดเลือกคอลัมน์ที่ต้องการใช้งาน ประกอบด้วย
# 1.ลำดับ
#
# 2.ภูมิภาค
#
# 3.จังหวัด
#
# 4.Area
#
# 5.PSU_NO
#
# 6.เพศ
#
# 7.อายุ
#
# 8.ระดับการศึกษาสูงสุด
#
# 9.ระหว่าง 7 วันก่อนวันสัมภาษณ์ได้ทำงานที่ก่อให้เกิดรายได้/เงินเดือน/ค่าจ้าง/ผลกำไร/ผลตอบแทนหรือได้ทำงานในฐานะช่วยธุรกิจของ
#
# 10.ไม่ได้ทำงานระหว่าง 7 วันก่อนวันสัมภาษณ์ยังได้รับค่าจ้าง/เงินเดือนหรือผลประโยชน์อื่น ๆ หรือผลกำไรจากงานหรือธุรกิจในระหว่า
#
# 11.มีงาน/ธุรกิจ/กิจการที่จะกลับไปทำ
#
# 12.

# %%
data_choose_colume = Data_ori[['NUM_B','CWT','AREA','PSU_NO','SEX','AGE','GRADE_B','SICK_ANNUAL','WK_7DAY','RECEIVE','RETURN','OCCUP','STATUS','MAIN_HR','TOTAL_HR','APPROX','WORK_STA','PRL_TECH','SICK_ANNUAL','SOC_SEC','CON_WORK','WORKPROB','COND','UNSAFE']]

# %%
data_choose_colume
# Out:
#          NUM_B  CWT  AREA  PSU_NO SEX AGE GRADE_B SICK_ANNUAL WK_7DAY RECEIVE  \
# 0            1   10     1       1   2  89     214                   2       2
# 1            2   10     1       1   2  56     520                   2       2
# 2            3   10     1       1   1  28     610                   2       2
# 3            4   10     1       1   1  47     210                   1
# 4            5   10     1       1   2  45     210                   1
# ...        ...  ...   ...     ...  ..  ..     ...         ...     ...     ...
# 208893  208894   96     1      18   1   9     110
# 208894  208895   96     1      18   1  43     210                   1
# 208895  208896   96     1      18   2  48       0                   1
# 208896  208897   96     1      18   2  18     210           1       1
# 208897  208898   96     1      18   2   0
#
#         ... TOTAL_HR APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK  \
# 0       ...
# 1       ...
# 2       ...
# ...

# %% [markdown]
# > คัดเลือกเฉพาะข้อมูลของกรุงเทพมหานคร

# %%
data_CWT = data_choose_colume[data_choose_colume.CWT == 10]
data_CWT
# Out:
#       NUM_B  CWT  AREA  PSU_NO SEX AGE GRADE_B SICK_ANNUAL WK_7DAY RECEIVE  \
# 0         1   10     1       1   2  89     214                   2       2
# 1         2   10     1       1   2  56     520                   2       2
# 2         3   10     1       1   1  28     610                   2       2
# 3         4   10     1       1   1  47     210                   1
# 4         5   10     1       1   2  45     210                   1
# ...     ...  ...   ...     ...  ..  ..     ...         ...     ...     ...
# 9245   9246   10     1      42   1  36     410           1       1
# 9246   9247   10     1      42   1   4
# 9247   9248   10     1      42   2  43     210           1       1
# 9248   9249   10     1      42
# 9249   9250   10     1      42   2  52     520           1       1
#
#       ... TOTAL_HR APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...       48                                            3
# ...

# %% [markdown]
# > คัดเลือกผู้ที่มีงานทำ ประกอบด้วย
# F10 = 1 (ทำงาน)
# F11 = 1 (ได้รับค่าจ้างหรือเงินเดือน)
# F12 = 1 (มีงานหรือกิจการที่จะกลับไปทำ)

# %%
data_worker = data_CWT[(data_CWT.WK_7DAY == '1') | (data_CWT.RECEIVE == '1') | (data_CWT.RETURN == '1')]
data_worker
# Out:
#       NUM_B  CWT  AREA  PSU_NO SEX AGE GRADE_B SICK_ANNUAL WK_7DAY RECEIVE  \
# 3         4   10     1       1   1  47     210                   1
# 4         5   10     1       1   2  45     210                   1
# 8         9   10     1     151   2  25     210           2       1
# 10       11   10     1     151   1  45     210           1       1
# 11       12   10     1     151   2  41       0                   1
# ...     ...  ...   ...     ...  ..  ..     ...         ...     ...     ...
# 9242   9243   10     1      42   1  51     520           1       1
# 9244   9245   10     1      42   2  43     310           1       1
# 9245   9246   10     1      42   1  36     410           1       1
# 9247   9248   10     1      42   2  43     210           1       1
# 9249   9250   10     1      42   2  52     520           1       1
#
#       ... TOTAL_HR APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK  \
# 3     ...       48                                            3
# ...

# %%
data_worker.shape
# Out:
# (4761, 24)

# %% [markdown]
# > คัดเลือกสถานภาพการทำงาน

# %%
data_STATUS = data_worker[data_worker.STATUS.isin(['1','2','3','4','5','6','7'])]
data_STATUS
# Out:
#       NUM_B  CWT  AREA  PSU_NO SEX AGE GRADE_B SICK_ANNUAL WK_7DAY RECEIVE  \
# 3         4   10     1       1   1  47     210                   1
# 4         5   10     1       1   2  45     210                   1
# 8         9   10     1     151   2  25     210           2       1
# 10       11   10     1     151   1  45     210           1       1
# 11       12   10     1     151   2  41       0                   1
# ...     ...  ...   ...     ...  ..  ..     ...         ...     ...     ...
# 9242   9243   10     1      42   1  51     520           1       1
# 9244   9245   10     1      42   2  43     310           1       1
# 9245   9246   10     1      42   1  36     410           1       1
# 9247   9248   10     1      42   2  43     210           1       1
# 9249   9250   10     1      42   2  52     520           1       1
#
#       ... TOTAL_HR APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK  \
# 3     ...       48                                            3
# ...

# %% [markdown]
# > แรงงานในระบบตามเงื่อนไขที่ 1 คือ F25 = 5 : เป็นลูกจ้างรัฐวิสาหกิจ

# %%
data_STATUS5 = data_STATUS[data_STATUS.STATUS == '5']
data_STATUS5
# Out:
#       NUM_B  CWT  AREA  PSU_NO SEX AGE GRADE_B SICK_ANNUAL WK_7DAY RECEIVE  \
# 115     116   10     1       1   1  49     610                   1
# 135     136   10     1       2   2  55     310                   1
# 451     452   10     1       3   1  55     610                   1
# 589     590   10     1     154   1  42     610                   1
# 631     632   10     1      53   2  57     610                   1
# ...     ...  ...   ...     ...  ..  ..     ...         ...     ...     ...
# 9028   9029   10     1     241   2  36     610                   1
# 9094   9095   10     1     187   2  37     610                   1
# 9142   9143   10     1     291   1  47     210                   1
# 9143   9144   10     1     291   2  46     210                   1
# 9172   9173   10     1      44   1  30     410                   1
#
#       ... TOTAL_HR APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK  \
# 115   ...       40  70000
# 135   ...       35   8000
# ...

# %% [markdown]
# > แรงงานในระบบตามเงื่อนไขที่ 2 คือ F25 = 4 : เป็นลูกจ้างรัฐบาล และ F46 = 1,2,3

# %%
data_STATUS4 = data_STATUS[data_STATUS.STATUS == '4']
data_STATUS4
# Out:
#       NUM_B  CWT  AREA  PSU_NO SEX AGE GRADE_B SICK_ANNUAL WK_7DAY RECEIVE  \
# 32       33   10     1      51   2  32     410           1       1
# 48       49   10     1      51   2  39     610                   1
# 53       54   10     1      51   1  44     310                   1
# 59       60   10     1      51   1  35     410           1       1
# 78       79   10     1     201   1  38     610                   1
# ...     ...  ...   ...     ...  ..  ..     ...         ...     ...     ...
# 9078   9079   10     1     136   1  26     410                   1
# 9082   9083   10     1     187   2  51     610                   1
# 9180   9181   10     1      37   1  33     610                   1
# 9186   9187   10     1      37   1  28     610                   1
# 9245   9246   10     1      42   1  36     410           1       1
#
#       ... TOTAL_HR APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK  \
# 32    ...       35  10000        4                    1       1
# ...

# %%
data_STATUS4_123 = data_STATUS4[(data_STATUS4.WORK_STA == '1') | (data_STATUS4.WORK_STA == '2') | (data_STATUS4.WORK_STA == '3')]
data_STATUS4_123
# Out:
#       NUM_B  CWT  AREA  PSU_NO SEX AGE GRADE_B SICK_ANNUAL WK_7DAY RECEIVE  \
# 48       49   10     1      51   2  39     610                   1
# 53       54   10     1      51   1  44     310                   1
# 78       79   10     1     201   1  38     610                   1
# 95       96   10     1     201   2  32     710                   1
# 185     186   10     1     152   2  44     610                   1
# ...     ...  ...   ...     ...  ..  ..     ...         ...     ...     ...
# 9076   9077   10     1     136   1  27     410                   1
# 9078   9079   10     1     136   1  26     410                   1
# 9082   9083   10     1     187   2  51     610                   1
# 9180   9181   10     1      37   1  33     610                   1
# 9186   9187   10     1      37   1  28     610                   1
#
#       ... TOTAL_HR APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK  \
# 48    ...       35  35000        1
# ...

# %% [markdown]
# > แรงงานในระบบตามเงื่อนไขที่ 3 คือ F25 = 4 : เป็นลูกจ้างรัฐบาล และ F46 = 4 : ลูกจ้างชั่วคราว/ผู้รับเหมา และ F48 = 1 : ได้รับสิทธิลาป่วย/ลาพักร้อน

# %%
data_STATUS4_4_1 = data_STATUS[(data_STATUS.STATUS == '4') & (data_STATUS.WORK_STA == '4') & (data_STATUS.SICK_ANNUAL == '1')]
data_STATUS4_4_1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-dee17bfccad4> in <module>
# ----> 1 data_STATUS4_4_1 = data_STATUS4[(data_STATUS4.WORK_STA == 4) & (data_STATUS4.SICK_ANNUAL == 1)]
#       2 data_STATUS4_4_1
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/arraylike.py in __rand__(self, other)
#      64     @unpack_zerodim_and_defer("__rand__")
#      65     def __rand__(self, other):
# ---> 66         return self._logical_method(other, roperator.rand_)
#      67
#      68     @unpack_zerodim_and_defer("__or__")
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _arith_method(self, other, op)
# ...

# %% [markdown]
# > แรงงานในระบบตามเงื่อนไขที่ 4 คือ F25 = 4 : เป็นลูกจ้างรัฐบาล และ F46 = 4 : ลูกจ้างชั่วคราว/ผู้รับเหมา และ F49 = 1,2,3,4 : เป็นผู้ประกันตน

# %% [markdown]
# > แรงงานในระบบตามเงื่อนไขที่ 5 คือ F25 = 4 : เป็นลูกจ้างรัฐบาล และ F46 = 4 : ลูกจ้างชั่วคราว/ผู้รับเหมา และ F49 = 5 : ไม่เป็นผู้ประกันตน และ F50 = 1 ทำงานต่อเนื่อง/ได้ค่าจ้างตามตกลง
