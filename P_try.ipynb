# %% [markdown]
# <a href="https://colab.research.google.com/github/623020514-5/stat-Ubon/blob/main/P_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
Data_ori = pd.read_csv('/content/drive/MyDrive/โครงงานสหกิจ/IES 2565 (2022)/Microdata IES 2565/Microdata IES 2565_N.csv')
Data_ori
# Out:
#         REG  CWT  AREA  PSU_NO  EA_SET SAMSET  MONTH  YR  HH_NO  TYPE  ...  \
# 0         1   10     1       1       1      D      7  65      7     1  ...
# 1         1   10     1       1       1      D      7  65      7     1  ...
# 2         1   10     1       1       1      D      7  65      7     1  ...
# 3         1   10     1       1       1      D      7  65      8     1  ...
# 4         1   10     1       1       1      D      7  65      8     1  ...
# ...     ...  ...   ...     ...     ...    ...    ...  ..    ...   ...  ...
# 208893    5   96     1      18       1      D      9  65      4     1  ...
# 208894    5   96     1      18       1      D      9  65      5     1  ...
# 208895    5   96     1      18       1      D      9  65      5     1  ...
# 208896    5   96     1      18       1      D      9  65      5     1  ...
# 208897    5   96     1      18       1      D      9  65      5     1  ...
#
# ...

# %%
data_choose_colume = Data_ori[['REG','CWT','AREA','PSU_NO','SEX','AGE','GRADE_B','OCCUP','STATUS','MAIN_HR','TOTAL_HR','APPROX','WORK_STA','PRL_TECH','SICK_ANNUAL','SOC_SEC','CON_WORK','WORKPROB','COND','UNSAFE']]

# %%
data_choose_colume
# Out:
#         REG  CWT  AREA  PSU_NO SEX AGE GRADE_B OCCUP STATUS MAIN_HR TOTAL_HR  \
# 0         1   10     1       1   2  89     214
# 1         1   10     1       1   2  56     520
# 2         1   10     1       1   1  28     610  5223      6
# 3         1   10     1       1   1  47     210  7313      2      48       48
# 4         1   10     1       1   2  45     210  7313      3      48       48
# ...     ...  ...   ...     ...  ..  ..     ...   ...    ...     ...      ...
# 208893    5   96     1      18   1   9     110
# 208894    5   96     1      18   1  43     210  6112      2      30       30
# 208895    5   96     1      18   2  48       0  6112      3      30       30
# 208896    5   96     1      18   2  18     210  5246      6      48       48
# 208897    5   96     1      18   2   0
#
#        APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK WORKPROB COND  \
# 0
# 1
# 2
# 3                                                 3                 0    4
# ...

# %%
data_STATUS = data_choose_colume[data_choose_colume.STATUS.isin(['1','2','3','4','5','6','7'])]
data_STATUS
# Out:
#         REG  CWT  AREA  PSU_NO SEX AGE GRADE_B OCCUP STATUS MAIN_HR TOTAL_HR  \
# 2         1   10     1       1   1  28     610  5223      6
# 3         1   10     1       1   1  47     210  7313      2      48       48
# 4         1   10     1       1   2  45     210  7313      3      48       48
# 8         1   10     1     151   2  25     210  5223      6      56       56
# 10        1   10     1     151   1  45     210  5223      6      48       48
# ...     ...  ...   ...     ...  ..  ..     ...   ...    ...     ...      ...
# 208889    5   96     1      18   2  32     310  5246      6      48       48
# 208890    5   96     1      18   2  70     214  6112      2      30       30
# 208894    5   96     1      18   1  43     210  6112      2      30       30
# 208895    5   96     1      18   2  48       0  6112      3      30       30
# 208896    5   96     1      18   2  18     210  5246      6      48       48
#
# ...

# %%
data_REG = data_STATUS[data_STATUS.REG < 2]
data_REG
# Out:
#       REG  CWT  AREA  PSU_NO SEX AGE GRADE_B OCCUP STATUS MAIN_HR TOTAL_HR  \
# 2       1   10     1       1   1  28     610  5223      6
# 3       1   10     1       1   1  47     210  7313      2      48       48
# 4       1   10     1       1   2  45     210  7313      3      48       48
# 8       1   10     1     151   2  25     210  5223      6      56       56
# 10      1   10     1     151   1  45     210  5223      6      48       48
# ...   ...  ...   ...     ...  ..  ..     ...   ...    ...     ...      ...
# 9242    1   10     1      42   1  51     520  8121      6      48       48
# 9244    1   10     1      42   2  43     310  9112      6      48       48
# 9245    1   10     1      42   1  36     410  5414      4      35       35
# 9247    1   10     1      42   2  43     210  9112      6      48       48
# 9249    1   10     1      42   2  52     520  9121      6      48       48
#
#      APPROX WORK_STA PRL_TECH SICK_ANNUAL SOC_SEC CON_WORK WORKPROB COND  \
# 2
# ...

# %%
data_WORKSTA_formal1 = data_REG[data_REG.WORK_STA.isin(['1','2','3'])]
data_WORKSTA_formal1
# Out:
#       REG  CWT  AREA  PSU_NO SEX AGE GRADE_B OCCUP STATUS MAIN_HR TOTAL_HR  \
# 48      1   10     1      51   2  39     610  2212      4      35       35
# 53      1   10     1      51   1  44     310  9613      4      35       35
# 78      1   10     1     201   1  38     610  4110      4      35       35
# 95      1   10     1     201   2  32     710  2120      4      35       35
# 185     1   10     1     152   2  44     610  2341      4      35       35
# ...   ...  ...   ...     ...  ..  ..     ...   ...    ...     ...      ...
# 9076    1   10     1     136   1  27     410   210      4      40       40
# 9078    1   10     1     136   1  26     410   210      4      40       40
# 9082    1   10     1     187   2  51     610  4312      4      35       35
# 9180    1   10     1      37   1  33     610  2212      4      35       35
# 9186    1   10     1      37   1  28     610  2211      4      35       35
#
# ...

# %%
data_WORKSTA_formal2 = data_REG[data_REG.WORK_STA == '4']
data_WORKSTA_formal2
# Out:
#       REG  CWT  AREA  PSU_NO SEX AGE GRADE_B OCCUP STATUS MAIN_HR TOTAL_HR  \
# 32      1   10     1      51   2  32     410  9121      4      35       35
# 59      1   10     1      51   1  35     410  3213      4      45       45
# 136     1   10     1       2   1  51     310  8322      4      48       48
# 455     1   10     1       3   1  25     610  4132      4      35       35
# 527     1   10     1     103   2  39     210  9613      4      49       49
# 530     1   10     1     103   1  26     210  9611      4      49       49
# 541     1   10     1     103   1  55     310  9629      4      35       35
# 977     1   10     1     256   1  52     410  4110      4      40       40
# 1499    1   10     1       9   2  50     980  6113      4      42       42
# 1504    1   10     1     209   1  28     410  8322      4      35       35
# 1577    1   10     1     209   1  21     310  9611      4      48       48
# ...

# %%
data_PRL_TECH = data_REG[data_REG.PRL_TECH.isin(['1','2'])]
data_PRL_TECH
# Out:
#       REG  CWT  AREA  PSU_NO SEX AGE GRADE_B OCCUP STATUS MAIN_HR TOTAL_HR  \
# 8       1   10     1     151   2  25     210  5223      6      56       56
# 10      1   10     1     151   1  45     210  5223      6      48       48
# 11      1   10     1     151   2  41       0  5211      1      48       48
# 12      1   10     1     151   1  20     210  5223      6      48       48
# 13      1   10     1     151   1  32     210  5211      6      56       56
# ...   ...  ...   ...     ...  ..  ..     ...   ...    ...     ...      ...
# 9241    1   10     1      42   2  52     610  2423      6      48       48
# 9242    1   10     1      42   1  51     520  8121      6      48       48
# 9244    1   10     1      42   2  43     310  9112      6      48       48
# 9247    1   10     1      42   2  43     210  9112      6      48       48
# 9249    1   10     1      42   2  52     520  9121      6      48       48
#
# ...
